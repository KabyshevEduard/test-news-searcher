# %%
from sentence_transformers import SentenceTransformer

# %%
model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-mpnet-base-v2')

# %%
from datasets import load_dataset

# %%
dataset = load_dataset("IlyaGusev/gazeta")
# Out:
# ...
# Generating test split: 100%|██████████| 6793/6793 [00:00<00:00, 136227.79 examples/s]

# %%
dataset['train']
# Out:
# Dataset({
#     features: ['text', 'summary', 'title', 'date', 'url'],
#     num_rows: 60964
# })

# %%
import json

def get_embeddings(text_list):
    encoded_input = model.encode(
        text_list
    )
    emb_list = encoded_input.tolist()
    return json.dumps(emb_list)
# Out:
# <class 'str'>

# %%
embeddings_dataset = dataset['train'].map(
    lambda x: {"embeddings": get_embeddings(x['summary'])}
)
# Out:
# Map: 100%|██████████| 60964/60964 [18:58<00:00, 53.54 examples/s]

# %%
embeddings_dataset
# Out:
# Dataset({
#     features: ['text', 'summary', 'title', 'date', 'url', 'embeddings'],
#     num_rows: 60964
# })

# %%
embeddings_dataset.to_csv('/Users/eduardkabyshev/Desktop/test-text-search/news_train_emb.csv')
# Out:
# Creating CSV from Arrow format: 100%|██████████| 61/61 [00:17<00:00,  3.42ba/s]
# 1565621514
